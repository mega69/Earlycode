# %%
#assignment 
# generate a sales data for january through decenber for 28 days 
# the sales range from 1000000 to 10000000
# for each day calculate the sales across all the month

# %%
#day 18 pandasone


import numpy as np
import pandas as pd

# %%
DAYS = 28
SALES_MIN = 1_000_000
SALES_MAX = 10_000_000
MONTHS = [ 'JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'JUL', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC']
sitno = np.arange(1,29)
np.random.seed(5)
score = np.random.randint(1000000,10000000,336)
score = score.reshape(28, 12)
df =pd.DataFrame(data =score, index= sitno, columns=MONTHS)
df
# Out:
#         JAN      FEB      MAR      APR      MAY      JUN      JUL      AUG  \
# 1   3115790  2956982  3758032  1558088  2214875  1950159  5386791  1683088
# 2   3787284  5422742  1740989  9194194  2021290  8356457  7023041  1833746
# 3   4027714  4928388  4732585  4604435  7144147  6677330  3683761  3952813
# 4   6519438  8772059  8368605  3347861  4756423  6808656  6132302  4171290
# 5   7291600  6293445  8229858  6681560  1697741  3388342  2953003  8592680
# 6   6347726  1307294  9188754  2090695  8075030  5681992  6242924  4871358
# 7   3744500  8187269  2515196  1581848  4354849  2552860  6015366  6605923
# 8   1097426  7307124  1271697  8728150  5984914  3562217  8217930  1711199
# 9   6945737  2425471  2375838  8454990  2330882  8630202  4683464  6563387
# 10  2027068  4271880  9677024  3664079  9296995  1399460  1072578  3612187
# 11  1574038  9553368  4037888  9909901  3955529  5872512  2347751  6258105
# ...

# %%
np.random.seed(5)
sales_value = np.random.randint(1000000,10000000,336).reshape(28,12)
df = pd.DataFrame(data=sales-, index=sitno, columns=cols)
df
# Out:
#         JAN      FEB      MAR      APR      MAY      JUN      JUL      AUG  \
# 1   3115790  2956982  3758032  1558088  2214875  1950159  5386791  1683088
# 2   3787284  5422742  1740989  9194194  2021290  8356457  7023041  1833746
# 3   4027714  4928388  4732585  4604435  7144147  6677330  3683761  3952813
# 4   6519438  8772059  8368605  3347861  4756423  6808656  6132302  4171290
# 5   7291600  6293445  8229858  6681560  1697741  3388342  2953003  8592680
# 6   6347726  1307294  9188754  2090695  8075030  5681992  6242924  4871358
# 7   3744500  8187269  2515196  1581848  4354849  2552860  6015366  6605923
# 8   1097426  7307124  1271697  8728150  5984914  3562217  8217930  1711199
# 9   6945737  2425471  2375838  8454990  2330882  8630202  4683464  6563387
# 10  2027068  4271880  9677024  3664079  9296995  1399460  1072578  3612187
# 11  1574038  9553368  4037888  9909901  3955529  5872512  2347751  6258105
# ...
